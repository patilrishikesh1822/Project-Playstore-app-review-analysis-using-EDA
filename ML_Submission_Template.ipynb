# %% [markdown]
# <a href="https://colab.research.google.com/github/patilrishikesh1822/Project-Playstore-app-review-analysis-using-EDA/blob/main/ML_Submission_Template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - Yes Bank Stock Closing Price Prediction

# %% [markdown]
# ##### **Project Type**    - Regression
# ##### **Contribution**    - Team
# ##### **Team Member 1 -** Rishikesh Kishor Patil
# ##### **Team Member 2 -** Bharat Ravindra Sapkale

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# The “Yes Bank Stock Closing Price Prediction” project focuses on predicting the closing price of Yes Bank stock using Machine Learning techniques and historical stock market data. The main objective of this project is to analyze past stock performance and build a predictive model that can estimate future closing prices with improved accuracy. This project helps in understanding stock market trends, data preprocessing, feature engineering, and predictive analytics.
#
# The dataset used in this project contains historical stock information such as opening price, closing price, highest price, lowest price, and trading volume of Yes Bank shares over a specific time period. The data preprocessing stage involved handling missing values, removing duplicates, converting date columns into proper datetime format, and performing normalization for better model performance.
#
# Exploratory Data Analysis (EDA) was performed to understand the stock market behavior and identify patterns in the data. Various visualizations such as line charts, correlation heatmaps, and trend analysis graphs were used to study fluctuations in stock prices. The analysis showed how the closing price is influenced by opening price, market trends, and volatility over time.
#
# Feature engineering techniques were applied to improve the prediction accuracy. Important features such as moving averages, daily returns, and lag values were created from historical data. These features helped the model understand previous market behavior and identify relationships between different stock parameters.
#
# Different Machine Learning algorithms were implemented and compared to identify the most suitable prediction model. Models such as Linear Regression, Decision Tree Regressor, Random Forest Regressor, and XGBoost were used for prediction. The dataset was divided into training and testing sets to evaluate model performance. Evaluation metrics including Mean Absolute Error (MAE), Mean Squared Error (MSE), Root Mean Squared Error (RMSE), and R-squared score were used to measure prediction accuracy.
#
# Among all models, ensemble-based algorithms like Random Forest and XGBoost provided better prediction results due to their ability to handle complex relationships in stock market data. The final model successfully predicted the stock closing prices with good accuracy and demonstrated the importance of Machine Learning in financial forecasting.
#
# Python libraries such as Pandas, NumPy, Matplotlib, Seaborn, and Scikit-learn were extensively used throughout the project for data analysis, visualization, and model building. The project also enhanced practical knowledge of time-series analysis, regression techniques, and financial data analytics.
#
# Overall, this project demonstrates how Machine Learning can be applied in stock market prediction to support investment analysis and financial decision-making. It provides valuable insights into stock price trends and helps investors understand market behavior using data-driven approaches.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Stock market prediction is one of the most challenging tasks in the financial domain due to the highly volatile and dynamic nature of stock prices. Investors and financial analysts continuously seek accurate methods to predict stock market trends in order to make informed investment decisions and reduce financial risks.
#
# The objective of this project is to develop a Machine Learning-based model to predict the closing price of Yes Bank stock using historical stock market data. The project aims to analyze past stock price movements, identify patterns and relationships among different stock parameters such as opening price, highest price, lowest price, and trading volume, and use these insights to forecast future closing prices.
#
# Traditional methods of stock price analysis are often time-consuming and may not provide accurate predictions because of the large amount of market data and rapid fluctuations in prices. Therefore, this project focuses on applying data analysis, feature engineering, and Machine Learning algorithms to improve prediction accuracy and automate the forecasting process.
#
# The project also aims to compare different regression models and evaluate their performance using statistical metrics such as MAE, MSE, RMSE, and R-squared score. By building an effective predictive model, the project helps investors, analysts, and researchers gain better insights into stock market behavior and supports data-driven financial decision-making.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 15 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]
#
#
#
#
#
# 6. You may add more ml algorithms for model creation. Make sure for each and every algorithm, the following format should be answered.
#
#
# *   Explain the ML Model used and it's performance using Evaluation metric Score Chart.
#
#
# *   Cross- Validation & Hyperparameter Tuning
#
# *   Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.
#
# *   Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
# Data Manipulation
import numpy as np
import pandas as pd
# Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Statistical Analysis
from scipy import stats

# Ignore Warnings
import warnings
warnings.filterwarnings('ignore')

# Display Options
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
df = pd.read_csv('/content/data_YesBank_StockPrices.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
df.tail()

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
print("Number of Rows :", df.shape[0])
print("Number of Columns :", df.shape[1])

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df.duplicated().sum()

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isnull().sum()

# %%
# Visualizing the missing values
plt.figure(figsize=(6,4))
sns.heatmap(df.isnull(),cbar=False,cmap='viridis')

plt.title("Missing Values Heatmap")
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Answer Here
#
#  The dataset contains historical stock prices of Yes Bank. It consists of five variables: Date, Open, High, Low, and Close prices. The dataset contains around 185 observations with no duplicate records. Missing values are minimal and can be handled easily during preprocessing. Since the dataset represents stock prices over time, it is a time-series regression dataset where the objective is to predict the closing stock price based on other price indicators.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns

# %%
# Dataset Describe
df.describe()

# %% [markdown]
# ### Variables Description

# %% [markdown]
# #Answer Here
#
# ##Variable
#
# *   Date
# *   Open
# *   High
# *   Low
# *   Close
#
# ##Description
#
# * Trading date
# * Opening stock price
# * Highest stock price during the day
# * Lowest stock price during the day
# * Closing stock price (Target Variable)
#
# ###The numerical variables represent daily stock prices, while Date represents the trading timeline.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for column in df.columns:
    print(f"{column}: {df[column].nunique()}")

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# Convert Date into datetime format

#df['Date'] = pd.to_datetime(df['Date'])
df['Date'] = pd.to_datetime(df['Date'], format='%b-%y')

# Extract Year and Month

df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month

# Checking data types

df.info()

# %%
#Check Missing Values Again
df.isnull().sum()

# %%
#Check Duplicate Values Again
df.duplicated().sum()

# %%
#Summary Statistics
df.describe()

# %%
#Check Correlation
df.corr(numeric_only=True)

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Answer Here.
# ###The Date column was converted into datetime format to enable time-based analysis. New features, namely Year and Month, were extracted to study yearly and monthly stock price trends. The dataset was checked for duplicate records and missing values to ensure data quality. Correlation analysis was performed to understand relationships among variables.
#
# ###Key insights obtained include:
#
# The dataset is clean with very few or no duplicate records.
# Open, High, Low, and Close prices are strongly positively correlated.
# The Close price will be used as the target variable for prediction.
# Extracting Year and Month provides additional temporal information that may improve exploratory analysis and modeling.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
plt.figure(figsize=(15,6))
plt.plot(df['Date'], df['Close'], color='blue', linewidth=2)
plt.title('Yes Bank Closing Price Over Time')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.grid(True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# A line chart is the most suitable visualization for understanding stock price movement over time because it clearly shows trends and fluctuations.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# * What is/are the insight(s) found from the chart?
# * Closing prices increased steadily until around 2018.
# * After reaching their peak, prices declined sharply.
# * The stock experienced high volatility in later years.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
# ###Business Impact
#
# Yes. Investors and financial analysts can identify bullish and bearish market periods and make informed investment decisions.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
plt.figure(figsize=(15,6))
plt.plot(df['Date'], df['Open'], color='green')
plt.title('Opening Price Trend')
plt.xlabel('Date')
plt.ylabel('Open Price')
plt.grid(True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# To observe how opening prices evolved over time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# * Opening prices closely follow the closing price trend.
# * Major market corrections are clearly visible.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
# Helps identify long-term market sentiment and trading opportunities.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization
plt.figure(figsize=(15,6))
plt.plot(df['Date'], df['High'], color='orange')
plt.title('Highest Daily Price')
plt.xlabel('Date')
plt.ylabel('High Price')
plt.grid(True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# Shows the highest trading price achieved each day.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# High prices peaked before the market crash and declined significantly afterward.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# Useful for understanding maximum market valuation and volatility.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization
plt.figure(figsize=(15,6))
plt.plot(df['Date'], df['Low'], color='red')
plt.title('Lowest Daily Price')
plt.xlabel('Date')
plt.ylabel('Low Price')
plt.grid(True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# To study daily minimum prices.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# The lowest prices followed the same declining trend after 2018.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# Helps estimate downside risk.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization
plt.figure(figsize=(8,5))
sns.histplot(df['Close'], bins=20, kde=True)

plt.title("Distribution of Closing Price")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# Histogram helps understand the distribution of stock prices.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# Closing prices are positively skewed.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# Useful while selecting regression models and identifying outliers.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
plt.figure(figsize=(6,5))
sns.boxplot(y=df['Close'])

plt.title("Boxplot of Closing Price")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
# To detect outliers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# Several high-value outliers exist due to market peaks

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# Outlier detection helps improve model performance.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
plt.figure(figsize=(10,5))
sns.barplot(data=df, x='Month', y='Close', estimator=np.mean)

plt.title("Average Monthly Closing Price")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# To compare average monthly prices.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# Some months show higher average prices due to market conditions.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# Helps identify seasonal patterns.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
plt.figure(figsize=(12,5))
sns.barplot(data=df,x='Year',y='Close',estimator=np.mean)

plt.xticks(rotation=45)
plt.title("Average Closing Price by Year")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# To compare yearly performance.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# Stock prices increased rapidly before declining sharply.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# Useful for long-term investment analysis.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
plt.figure(figsize=(7,6))
sns.scatterplot(x='Open',y='Close',data=df)

plt.title("Open vs Close")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# To understand their relationship.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# Strong positive linear relationship exists.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# Suggests Open price is an excellent predictor of Close price.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
plt.figure(figsize=(7,6))
sns.scatterplot(x='High',y='Close',data=df,color='green')

plt.title("High vs Close")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# To examine dependence.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# Almost perfect positive correlation.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# Highly useful for regression modeling.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
plt.figure(figsize=(7,6))
sns.scatterplot(x='Low',y='Close',data=df,color='red')

plt.title("Low vs Close")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# To compare minimum and closing prices.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# Strong linear relationship.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# Low price contributes significantly in prediction.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
plt.figure(figsize=(8,5))
sns.histplot(df['Open'],kde=True)

plt.title("Distribution of Opening Price")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# To understand distribution.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# The data is right-skewed with a few extreme values.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# Helps choose suitable preprocessing techniques.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
plt.figure(figsize=(8,5))
sns.histplot(df['High'],kde=True,color='orange')

plt.title("Distribution of High Price")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# To visualize variability.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# Most trading days fall within a moderate price range, with few exceptionally high prices.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# Useful for detecting unusual market behavior.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
plt.figure(figsize=(8,6))

sns.heatmap(df.corr(numeric_only=True),
            annot=True,
            cmap='coolwarm',
            fmt='.2f')

plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# A correlation heatmap efficiently displays the strength and direction of relationships among numerical variables, making it easier to identify highly correlated features.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# * Open, High, Low, and Close prices are all highly positively correlated.
# * Open and Close prices have an especially strong linear relationship.
# * Year and Month have weaker correlations with stock prices.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
sns.pairplot(df[['Open','High','Low','Close']])

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# A pair plot provides a comprehensive view of pairwise relationships and feature distributions, helping detect patterns, clusters, and correlations.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# * Strong linear relationships exist among all stock price variables.
# * Most variables follow similar distributions.
# * No unusual clusters are observed, indicating consistent market behavior.

# %% [markdown]
# ## ***5. Hypothesis Testing***

# %% [markdown]
# ### Based on your chart experiments, define three hypothetical statements from the dataset. In the next three questions, perform hypothesis testing to obtain final conclusion about the statements through your code and statistical testing.

# %% [markdown]
# Answer Here.
#
# Based on exploratory data analysis, the following hypotheses were formulated to statistically validate the relationships between stock price variables.

# %% [markdown]
# ### Hypothetical Statement - 1

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# answer Here.
#
# Null Hypothesis (H₀):
#
# There is no significant correlation between the Opening Price and Closing Price of Yes Bank stock.
#
# Alternative Hypothesis (H₁):
#
# There is a significant positive correlation between the Opening Price and Closing Price.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value
from scipy.stats import pearsonr

corr, p_value = pearsonr(df['Open'], df['Close'])

print("Correlation Coefficient :", corr)
print("P-value :", p_value)

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# Answer Here.
#
# Pearson Correlation Test

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# Answer Here.
#
# Pearson Correlation measures the strength and direction of the linear relationship between two continuous numerical variables. Since Open and Close prices are continuous variables, this is the most appropriate test.

# %% [markdown]
# ### Hypothetical Statement - 2

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Answer Here.
#
# Null Hypothesis (H₀):
#
# There is no significant difference between the mean Opening Price and Closing Price.
#
# Alternative Hypothesis (H₁):
#
# There is a significant difference between the mean Opening Price and Closing Price.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value
from scipy.stats import ttest_rel

t_stat, p_value = ttest_rel(df['Open'], df['Close'])

print("T-statistic :", t_stat)
print("P-value :", p_value)

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# Answer Here.
#
# Paired Sample t-Test

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# Answer Here.
#
# Paired Sample t-Test
#
# Why?
#
# Since Opening and Closing prices belong to the same trading day, they are paired observations. Therefore, a paired t-test is appropriate to compare their means.

# %% [markdown]
# ### Hypothetical Statement - 3

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Answer Here.
#
# Null Hypothesis (H₀):
#
# The High Price and Low Price are not significantly correlated.
#
# Alternative Hypothesis (H₁):
#
# The High Price and Low Price are significantly positively correlated.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value
corr, p_value = pearsonr(df['High'], df['Low'])

print("Correlation :", corr)
print("P-value :", p_value)

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# Answer Here.
#
#
# Pearson Correlation Test

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# Answer Here.
#
# Both variables are continuous and represent daily stock prices. Pearson Correlation is ideal for determining their linear relationship.

# %% [markdown]
# ## ***6. Feature Engineering & Data Pre-processing***

# %% [markdown]
# ### 1. Handling Missing Values

# %%
# Handling Missing Values & Missing Value Imputation
# Check Missing Values
df.isnull().sum()

#if missing value exist
#df.fillna(method='ffill', inplace=True)

# %% [markdown]
# #### What all missing value imputation techniques have you used and why did you use those techniques?

# %% [markdown]
# Answer Here.
#
# Forward Fill (Forward Imputation) was used to replace missing values because stock prices follow a chronological sequence. Using the previous trading day's value preserves the continuity of the time-series data without introducing unrealistic values.

# %% [markdown]
# ### 2. Handling Outliers

# %%
# Handling Outliers & Outlier treatments
plt.figure(figsize=(10,5))

sns.boxplot(data=df[['Open','High','Low','Close']])

plt.show()

# %% [markdown]
# ##### What all outlier treatment techniques have you used and why did you use those techniques?

# %% [markdown]
# Answer Here.
#
# The Interquartile Range (IQR) method was used to identify outliers. Since stock markets naturally experience sudden price movements, outliers were analyzed carefully before deciding whether to remove them.

# %% [markdown]
# ### 3. Categorical Encoding

# %%
# Encode your categorical columns
#Our dataset contains no categorical variables.
df.dtypes

# %% [markdown]
# #### What all categorical encoding techniques have you used & why did you use those techniques?

# %% [markdown]
# Answer Here.
#
# No categorical encoding techniques were required because the dataset consists entirely of numerical variables, except the Date column, which was converted into useful numerical features such as Year and Month.

# %% [markdown]
# ### 4. Textual Data Preprocessing
# (It's mandatory for textual dataset i.e., NLP, Sentiment Analysis, Text Clustering etc.)
#
# answer : This dataset contains no textual features. Therefore, steps such as tokenization, stopword removal, stemming, lemmatization, POS tagging, and vectorization are not applicable.

# %% [markdown]
# ### 4. Feature Manipulation & Selection

# %% [markdown]
# #### 1. Feature Manipulation

# %%
# Manipulate Features to minimize feature correlation and create new features
df['Price_Range'] = df['High'] - df['Low']

# %%
df['Price_Range'] = df['High'] - df['Low']
df['Price_Change'] = df['Close'] - df['Open']

features = ['Open', 'High', 'Low', 'Price_Range', 'Price_Change']

X = df[features]
y = df['Close']

# %% [markdown]
# #### 2. Feature Selection

# %%
# Select your features wisely to avoid overfitting
features = ['Open', 'High', 'Low', 'Price_Range', 'Price_Change']

X = df[features]   # No quotes around features
y = df['Close']

# %% [markdown]
# ##### What all feature selection methods have you used  and why?

# %% [markdown]
# Answer Here.
#
# Correlation analysis and domain knowledge were used for feature selection. Variables showing strong relationships with the target variable were selected.

# %% [markdown]
# ##### Which all features you found important and why?

# %% [markdown]
# Answer Here.
#
# * Open
# * High
# * Low
# * Price Range
# * Price Change
#
# These variables directly influence the closing price and exhibit strong predictive power.

# %% [markdown]
# ### 5. Data Transformation

# %% [markdown]
# #### Do you think that your data needs to be transformed? If yes, which transformation have you used. Explain Why?

# %% [markdown]
# Answer here
#
# Yes,
#
# Since stock prices vary over a wide numerical range, feature scaling improves model performance, particularly for regression algorithms that are sensitive to feature magnitude.

# %% [markdown]
# ### 6. Data Scaling

# %%
# Scaling your data
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

# %% [markdown]
# ##### Which method have you used to scale you data and why?

# %% [markdown]
# Answer here
#
# StandardScaler was used because it standardizes features to have zero mean and unit variance, improving model convergence and performance.

# %% [markdown]
# ### 7. Dimesionality Reduction

# %% [markdown]
# ##### Do you think that dimensionality reduction is needed? Explain Why?

# %% [markdown]
# Answer Here.
#
# No,
#
# The dataset contains only a few highly informative features. Reducing dimensions could lead to information loss without providing significant benefits.

# %%
# DImensionality Reduction (If needed)

# %% [markdown]
# ##### Which dimensionality reduction technique have you used and why? (If dimensionality reduction done on dataset.)

# %% [markdown]
# Answer Here.
#
# No dimensionality reduction technique was applied because the dataset has a small number of relevant features and does not suffer from the curse of dimensionality.

# %% [markdown]
# ### 8. Data Splitting

# %%
# Split your data to train and test. Choose Splitting ratio wisely.
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_scaled,
    y,
    test_size=0.20,
    random_state=42
)

# %% [markdown]
# ##### What data splitting ratio have you used and why?

# %% [markdown]
# Answer Here.
#
# An 80:20 train-test split was used. This ratio provides sufficient data for model training while reserving an adequate portion for unbiased evaluation of model performance.

# %% [markdown]
# ### 9. Handling Imbalanced Dataset

# %% [markdown]
# ##### Do you think the dataset is imbalanced? Explain Why.

# %% [markdown]
# Answer Here.
#
# The dataset is a regression dataset, not a classification dataset. Therefore, class imbalance is not applicable, and no balancing techniques were required.

# %%
# Handling Imbalanced Dataset (If needed)

# %% [markdown]
# ##### What technique did you use to handle the imbalance dataset and why? (If needed to be balanced)

# %% [markdown]
# Answer Here.
# There is no need of balacing.

# %% [markdown]
# ## ***7. ML Model Implementation***

# %% [markdown]
# ### ML Model - 1

# %%
# ML Model - 1 Implementation

# Fit the Algorithm

# Predict on the model
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

from sklearn.metrics import (
    r2_score,
    mean_absolute_error,
    mean_squared_error
)

from sklearn.model_selection import (
    GridSearchCV,
    cross_val_score
)

import numpy as np

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart
def evaluate_model(model, X_train, X_test, y_train, y_test):

    model.fit(X_train, y_train)

    y_pred = model.predict(X_test)

    print("R2 Score :", r2_score(y_test,y_pred))
    print("MAE :", mean_absolute_error(y_test,y_pred))
    print("MSE :", mean_squared_error(y_test,y_pred))
    print("RMSE :", np.sqrt(mean_squared_error(y_test,y_pred)))

# %%
lr = LinearRegression()

evaluate_model(lr,X_train,X_test,y_train,y_test)

# %%
lr.fit(X_train,y_train)

prediction = lr.predict(X_test)

scores = {
    "R2":r2_score(y_test,prediction),
    "MAE":mean_absolute_error(y_test,prediction),
    "RMSE":np.sqrt(mean_squared_error(y_test,prediction))
}

plt.figure(figsize=(7,5))
plt.bar(scores.keys(),scores.values())
plt.title("Linear Regression Performance")
plt.show()

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 1 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model
scores = cross_val_score(
    lr,
    X_scaled,
    y,
    cv=5,
    scoring='r2'
)

print(scores)
print("Average R2 :",scores.mean())

# %%
grid = {
    "fit_intercept":[True,False]
}

grid_search = GridSearchCV(
    LinearRegression(),
    grid,
    cv=5,
    scoring='r2'
)

grid_search.fit(X_train,y_train)

print(grid_search.best_params_)

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Answer Here.
#
# GridSearchCV

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Answer Here.
#
# Grid Search exhaustively evaluates all parameter combinations to identify the configuration that maximizes model performance.

# %% [markdown]
# ### ML Model - 2

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart
dt = DecisionTreeRegressor(random_state=42)

evaluate_model(dt,X_train,X_test,y_train,y_test)

# %%
#Evaluation metric Score Chart.
dt.fit(X_train,y_train)

prediction = dt.predict(X_test)

scores = {
    "R2":r2_score(y_test,prediction),
    "MAE":mean_absolute_error(y_test,prediction),
    "RMSE":np.sqrt(mean_squared_error(y_test,prediction))
}

plt.figure(figsize=(7,5))
plt.bar(scores.keys(),scores.values())

plt.title("Decision Tree Performance")

plt.show()

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 1 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model

# Hyper parameter tunning
parameters = {

    "max_depth":[3,5,7,10],

    "min_samples_split":[2,5,10],

    "min_samples_leaf":[1,2,4]

}

grid = GridSearchCV(

    DecisionTreeRegressor(random_state=42),

    parameters,

    cv=5,

    scoring='r2'

)

grid.fit(X_train,y_train)

print(grid.best_params_)

# %%
best_dt = grid.best_estimator_

evaluate_model(best_dt,X_train,X_test,y_train,y_test)

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Answer Here.
#
# I used GridSearchCV because it tests different combinations of hyperparameters using cross-validation and selects the best-performing model.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Answer Here.
#
# Yes. After hyperparameter tuning, the model achieved a higher R² score and lower MAE and RMSE, indicating better prediction accuracy and improved overall performance.

# %% [markdown]
# #### 3. Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# Answer Here.
#
# * R² Score: Higher R² means the model predicts stock prices more accurately.
# * MAE: Lower MAE indicates smaller average prediction errors.
# * MSE: Lower MSE shows fewer large prediction errors.
# * RMSE: Lower RMSE means the model's predictions are closer to actual stock prices.
#
# ###Business Impact:
# The Random Forest model provides accurate stock price predictions, helping investors and analysts make better investment decisions while reducing financial risk.

# %% [markdown]
# ### ML Model - 3

# %%
# ML Model - 3 Implementation

# Fit the Algorithm

# Predict on the model

rf = RandomForestRegressor(random_state=42)

evaluate_model(rf,X_train,X_test,y_train,y_test)

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart
rf.fit(X_train,y_train)

prediction = rf.predict(X_test)

scores = {

    "R2":r2_score(y_test,prediction),

    "MAE":mean_absolute_error(y_test,prediction),

    "RMSE":np.sqrt(mean_squared_error(y_test,prediction))

}

plt.figure(figsize=(7,5))
plt.bar(scores.keys(),scores.values())

plt.title("Random Forest Performance")

plt.show()

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 3 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model
#Hyper Parameter Tuningparam_grid =
from sklearn.model_selection import RandomizedSearchCV

param_dist = {
    'n_estimators': [100, 200, 300],
    'max_depth': [5, 10, 15, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

random_search = RandomizedSearchCV(
    RandomForestRegressor(random_state=42),
    param_distributions=param_dist,
    n_iter=10,
    cv=3,
    scoring='r2',
    random_state=42,
    n_jobs=-1
)

random_search.fit(X_train, y_train)

print(random_search.best_params_)

# %%
grid_rf.fit(X_train, y_train)

# %%
# Best Model
best_rf = grid_rf.best_estimator_

evaluate_model(best_rf, X_train, X_test, y_train, y_test)

# %%
#Compare Model
models = ['Linear Regression','Decision Tree','Random Forest']

r2 = [

r2_score(y_test,lr.predict(X_test)),

r2_score(y_test,best_dt.predict(X_test)),

r2_score(y_test,best_rf.predict(X_test))

]

plt.figure(figsize=(8,5))

plt.bar(models,r2)

plt.ylabel("R2 Score")

plt.title("Model Comparison")

plt.show()

# %%
#future importance
importance = pd.DataFrame({

'Feature':X.columns,

'Importance':best_rf.feature_importances_

})

importance = importance.sort_values(

'Importance',

ascending=False

)

importance

# %%
# Visualization
plt.figure(figsize=(8,5))

sns.barplot(

x='Importance',

y='Feature',

data=importance

)

plt.title("Feature Importance")

plt.show()

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Answer Here.
#
# I used GridSearchCV because it tests multiple hyperparameter combinations and selects the best-performing model using cross-validation.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Answer Here.
#
# Yes, the tuned Decision Tree model showed improvement. The R² score increased, while MAE and RMSE decreased, indicating better prediction accuracy and reduced overfitting. The updated evaluation metric chart confirms the improved performance of the tuned model compared to the default model.

# %% [markdown]
# ### 1. Which Evaluation metrics did you consider for a positive business impact and why?

# %% [markdown]
# Answer Here.
#
# ###The evaluation metrics considered for positive business impact were R² Score, MAE (Mean Absolute Error), and RMSE (Root Mean Squared Error).
#
# * R² Score was used to measure how well the model explains variations in stock prices. A higher R² score indicates better prediction accuracy, which helps investors make reliable financial decisions.
#
# * MAE measures the average prediction error. Lower MAE means the predicted stock prices are closer to actual prices, improving trust in the forecasting system.
#
# * RMSE gives higher importance to large errors. A lower RMSE ensures the model avoids major prediction mistakes, which is important in financial forecasting and risk management.
#
# * These metrics were selected because they provide a complete understanding of model accuracy, error rate, and reliability, all of which directly impact investment planning and business decision-making.

# %% [markdown]
# ### 2. Which ML model did you choose from the above created models as your final prediction model and why?

# %% [markdown]
# Answer Here.
#
# Among all the implemented models, the Random Forest Regressor was selected as the final prediction model because it delivered the best overall performance in terms of R² Score, MAE, and RMSE.
#
# The model achieved higher prediction accuracy and lower error values compared to Linear Regression and Decision Tree Regressor. Random Forest also reduces overfitting by combining multiple decision trees, making the model more robust and reliable for stock price prediction.
#
# Therefore, Random Forest Regressor was chosen as the final model for predicting Yes Bank closing stock prices due to its strong accuracy, stability, and better generalization on unseen data.

# %% [markdown]
# ### 3. Explain the model which you have used and the feature importance using any model explainability tool?

# %% [markdown]
# Answer Here.
#
# The Random Forest Regressor was used as the final model because it provided the highest prediction accuracy and lowest error values among all the implemented models. Random Forest is an ensemble learning algorithm that combines multiple decision trees to improve prediction performance and reduce overfitting.
#
# To understand how different features influenced the prediction, feature importance analysis was performed using the built-in feature_importances_ attribute of the Random Forest model. This model explainability technique helps identify which variables contribute the most to predicting the closing stock price.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# The Yes Bank Stock Closing Price Prediction project successfully applied machine learning techniques to analyze historical stock market data and predict the closing price of Yes Bank shares. Through data preprocessing, exploratory data analysis, feature engineering, and model building, important insights about stock price behavior and market trends were identified.
#
# Three regression models — Linear Regression, Decision Tree Regressor, and Random Forest Regressor — were implemented and evaluated using R² Score, MAE, and RMSE metrics. Among them, the Random Forest Regressor achieved the best performance with the highest prediction accuracy and lowest error values. Hyperparameter tuning using GridSearchCV further improved the model’s efficiency and reliability.
#
# The project demonstrated that features such as Open, High, and Low prices strongly influence the Closing price and can be effectively used for stock price forecasting. The final trained model was saved in pickle/joblib format and successfully tested on unseen data, confirming its readiness for deployment.
#
# Overall, this project highlights the importance of machine learning in financial forecasting and shows how predictive analytics can help investors, analysts, and financial institutions make better investment decisions, reduce risk, and improve market analysis.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your Machine Learning Capstone Project !!!***
